# %%
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph
from reportlab.lib.styles import getSampleStyleSheet

# Read the content of the text file
with open('ait_paragraphs.txt', 'r') as file:
    text_content = file.read()

# Split the content into paragraphs
paragraphs = text_content.split('\n')

# Create a PDF document
pdf_filename = 'ait_paragraphs.pdf'
doc = SimpleDocTemplate(pdf_filename, pagesize=letter)
styles = getSampleStyleSheet()
story = []

# Add each paragraph to the story
for paragraph in paragraphs:
    p = Paragraph(paragraph, styles['Normal'])
    story.append(p)

# Build the PDF document
doc.build(story)

print(f"PDF file '{pdf_filename}' created successfully.")
# Out:
# PDF file 'ait_paragraphs.pdf' created successfully.

# %%
import requests
from bs4 import BeautifulSoup
import os
import re
from urllib.parse import urlparse, urljoin

# Function to extract only English words from text
def extract_english_words(text):
    # Remove HTML tags
    text = BeautifulSoup(text, "html.parser").get_text()
    # Tokenize and filter English words
    words = re.findall(r'\b[A-Za-z]+\b', text)
    return words

# Function to convert words list into paragraphs
def convert_to_paragraphs(words, max_words_per_paragraph=10):
    paragraphs = []
    paragraph = ""
    for word in words:
        # Append word to paragraph
        paragraph += word + " "
        # Check if paragraph length exceeds max_words_per_paragraph
        if len(paragraph.split()) >= max_words_per_paragraph:
            # Add paragraph to the list and reset paragraph
            paragraphs.append(paragraph.strip())
            paragraph = ""
    # Add any remaining words as the last paragraph
    if paragraph:
        paragraphs.append(paragraph.strip())
    return paragraphs

# Function for recursive crawling with depth and URL limits
def crawl(url, domain, visited, max_depth=3, max_urls=100):
    if url in visited or len(visited) >= max_urls:
        return
    visited.add(url)
    
    print(f"Crawling: {url}")
    
    try:
        # Send a GET request to the URL
        response = requests.get(url)
        # Extract text from HTML content
        html_content = response.content
        # Extract only English words from the text
        words = extract_english_words(html_content.decode('utf-8'))
        # Save document with source URL
        save_document(url, words)
        
        # Extract links from the page
        soup = BeautifulSoup(html_content, 'html.parser')
        links = soup.find_all('a', href=True)
        for link in links:
            href = link['href']
            # Make the URL absolute
            absolute_url = urljoin(url, href)
            # Check if the link is within the same domain
            if urlparse(absolute_url).netloc == domain:
                # Check if the depth limit is reached
                if max_depth > 1:
                    crawl(absolute_url, domain, visited, max_depth-1, max_urls)
    except Exception as e:
        print(f"Error crawling {url}: {e}")

# Function to save document with source URL
def save_document(url, words):
    # Extract domain name from URL
    domain_name = urlparse(url).netloc
    # Create folder if it doesn't exist
    folder_name = f"{domain_name}_documents"
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    # Generate file name from URL
    file_name = f"{folder_name}/{url.replace('/', '_')}.txt"
    # Write words to file
    with open(file_name, 'w') as f:
        f.write('\n'.join(words))

# Starting URL
start_url = 'https://ait.ac.th/'

# Extract domain from the starting URL
domain = urlparse(start_url).netloc

# Set of visited URLs to avoid revisiting the same page
visited = set()

# Start crawling with depth and URL limits
crawl(start_url, domain, visited, max_depth=3, max_urls=100)

print("Documents saved in separate folders.")
# Out:
# Crawling: https://ait.ac.th/
# Crawling: https://ait.ac.th/ait-boi-science-and-technology-park/
# Crawling: https://ait.ac.th/contact/
# Crawling: https://ait.ac.th/alumni/
# Crawling: https://ait.ac.th/about/
# Crawling: https://ait.ac.th/about/facts-and-figures/
# Crawling: https://ait.ac.th/about/rankings/
# Crawling: https://ait.ac.th/about/leadership/
# Crawling: https://ait.ac.th/about/meet-our-faculty/
# Crawling: https://ait.ac.th/about/meet-our-staff/
# Crawling: https://ait.ac.th/about/location/
# Crawling: https://ait.ac.th/academics/calendar/
# Crawling: https://ait.ac.th/academics/programs/
# Crawling: https://ait.ac.th/academics/study-options/
# Crawling: https://ait.ac.th/academics/student-opportunities/
# Crawling: https://ait.ac.th/academics/schools/
# Crawling: https://ait.ac.th/admissions/
# Crawling: https://ait.ac.th/eligibility/
# Crawling: https://ait.ac.th/financial-aid/
# Crawling: https://ait.ac.th/tuition-and-fees/
# Crawling: https://ait.ac.th/student-housing/
# Crawling: https://ait.ac.th/apply-online/
# Crawling: https://ait.ac.th/admissions/frequently-asked-questions/
# Crawling: https://ait.ac.th/research-overview/
# Crawling: https://ait.ac.th/research-themes/
# Crawling: https://ait.ac.th/research-and-publication/
# Crawling: https://ait.ac.th/research-projects/
# Crawling: https://ait.ac.th/know-our-researcher/
# Crawling: https://ait.ac.th/about/centers/
# Crawling: https://ait.ac.th/housing/
# Crawling: https://ait.ac.th/dining/
# Crawling: https://ait.ac.th/health-wellness/
# Crawling: https://ait.ac.th/cultural-diversity/
# Crawling: https://ait.ac.th/athletcis/
# Crawling: https://ait.ac.th/career-development/
# Crawling: https://ait.ac.th/facilities/
# Crawling: https://ait.ac.th/ait-conference-center/
# Crawling: https://ait.ac.th/virtual-tour/
# Crawling: https://ait.ac.th/climate-change/
# Crawling: https://ait.ac.th/smart-communities/
# Crawling: https://ait.ac.th/food-energy-water/
# Crawling: https://ait.ac.th/infrastructure/
# Crawling: https://ait.ac.th/technology-policy-society/
# Crawling: https://ait.ac.th/sustainability/
# Crawling: https://ait.ac.th/partners/
# Crawling: https://ait.ac.th/news/
# Crawling: https://ait.ac.th/events/
# Crawling: https://ait.ac.th/opportunities/
# Crawling: https://ait.ac.th/emergency-contacts-covid-19-management/
# Crawling: https://ait.ac.th
# Crawling: https://ait.ac.th/wp-content/uploads/2022/01/AIT-LINE-QR.png
# Error crawling https://ait.ac.th/wp-content/uploads/2022/01/AIT-LINE-QR.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Crawling: https://ait.ac.th/wp-content/uploads/2022/01/WECHAT-ACCOUNT-AIT-OFFICAL-QR-CODE.jpeg
# Error crawling https://ait.ac.th/wp-content/uploads/2022/01/WECHAT-ACCOUNT-AIT-OFFICAL-QR-CODE.jpeg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Crawling: https://ait.ac.th/research-centers/
# Crawling: https://ait.ac.th/branding/
# Crawling: https://ait.ac.th/a-z-units/
# Crawling: https://ait.ac.th/privacy-policy/
# Crawling: https://ait.ac.th/terms-conditions/
# Crawling: https://ait.ac.th/2023/11/ait-professors-shine-globally-recognized-among-worlds-top-2-of-influential-scientists-for-career-long-and-single-year-impact/
# Crawling: https://ait.ac.th/category/news/
# Crawling: https://ait.ac.th/wp-content/uploads/2023/11/faculty-ranking-2023-hires.jpg
# Error crawling https://ait.ac.th/wp-content/uploads/2023/11/faculty-ranking-2023-hires.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Crawling: https://ait.ac.th/cdn-cgi/l/email-protection#ae91dddbccc4cbcdda93e78ed9cfc0dacbca8ed7c1db8edac18eddcbcb8edac6c7dd8eddc7dacb88cfc3de95ccc1cad793edc6cbcdc58ec1dbda8edac6c7dd8eddc7dacb948ec6dadadedd948181cfc7da80cfcd80dac680
# Crawling: https://ait.ac.th/2024/03/ait-expresses-condolences-on-the-passing-away-of-professor-dr-za-chieh-moh/
# Crawling: https://ait.ac.th/2024/03/wepower-sar100-program-celebrates-women-engineers-in-south-asia/
# Crawling: https://ait.ac.th/2024/03/experts-discuss-gender-geopolitics-and-displacement-in-observance-of-womens-month-at-aits-international-conference/
# Crawling: https://ait.ac.th/2024/02/ait-students-explore-innovative-construction-techniques-at-terra-residence/
# Crawling: https://ait.ac.th/2024/02/ait-alumnus-support-the-water-engineering-and-management-laboratory/
# Crawling: https://ait.ac.th/2024/02/aits-school-of-engineering-and-technology-hosts-successful-open-house/
# Crawling: https://ait.ac.th/2023/10/aits-mba-and-badt-programs-achieve-top-ranking-in-thailand-for-employability-and-diversity-globally-recognized-in-qs-rankings/
# Crawling: https://ait.ac.th/cdn-cgi/l/email-protection#c6f9b5b3a4aca3a5b2fb8fe6b1a7a8b2a3a2e6bfa9b3e6b2a9e6b5a3a3e6b2aeafb5e6b5afb2a3e0a7abb6fda4a9a2bffb85aea3a5ade6a9b3b2e6b2aeafb5e6b5afb2a3fce6aeb2b2b6b5fce9e9a7afb2e8a7a5e8b2aee8
# Crawling: https://ait.ac.th/2022/04/targeted-businesses-to-enjoy-privileges-from-new-boi-designated-zone-for-ait/
# Crawling: https://ait.ac.th/cdn-cgi/l/email-protection
# Crawling: https://ait.ac.th/cdn-cgi/l/email-protection#99a6eaecfbf3fcfaeda4d0b9eef8f7edfcfdb9e0f6ecb9edf6b9eafcfcb9edf1f0eab9eaf0edfcbff8f4e9a2fbf6fde0a4daf1fcfaf2b9f6ecedb9edf1f0eab9eaf0edfca3b9f1edede9eaa3b6b6f8f0edb7f8fab7edf1b7
# Crawling: https://ait.ac.th/study/flexible-phd-option/
# Crawling: https://ait.ac.th/school/school-of-engineering-and-technology/
# Crawling: https://ait.ac.th/program/construction-engineering-and-infrastructure-management-ceim/
# Crawling: https://ait.ac.th/program/geotechnical-and-earth-resources-engineering-gte/
# Crawling: https://ait.ac.th/program/water-engineering-and-management-wem/
# Crawling: https://ait.ac.th/program/transportation-engineering-tre/
# Crawling: https://ait.ac.th/program/structural-engineering-ste/
# Crawling: https://ait.ac.th/program/industrial-and-manufacturing-engineering-ime/
# Crawling: https://ait.ac.th/program/computer-science/
# Crawling: https://ait.ac.th/program/information-management/
# Crawling: https://ait.ac.th/program/telecommunications-tc/
# Crawling: https://ait.ac.th/program/internet-of-things-iot-systems-engineering/
# Crawling: https://ait.ac.th/program/information-communication-technologies/
# Crawling: https://ait.ac.th/program/data-science-and-ai/
# Crawling: https://ait.ac.th/program/agri-business-management/
# Crawling: https://ait.ac.th/program/agricultural-systems-and-engineering/
# Crawling: https://ait.ac.th/program/food-innovation-nutrition-and-health-finh/
# Crawling: https://ait.ac.th/program/development-and-sustainability/
# Crawling: https://ait.ac.th/program/natural-resources-management/
# Crawling: https://ait.ac.th/program/development-planning-management-and-innovation/
# Crawling: https://ait.ac.th/program/society-and-environmental-governance/
# Crawling: https://ait.ac.th/program/urban-innovation-and-sustainability/
# Crawling: https://ait.ac.th/program/page-template-for-academic/
# Crawling: https://ait.ac.th/program/doctorate-of-business-administration-dba/
# Crawling: https://ait.ac.th/program/masters-in-business-analytics-digital-transformation/
# Crawling: https://ait.ac.th/program/masters-in-international-finance-m-msc-if/
# Crawling: https://ait.ac.th/program/disaster-preparedness-mitigation-and-management/
# Crawling: https://ait.ac.th/cdn-cgi/l/email-protection#087b6d7c696c65617b7b6167667b4869617c26696b267c60
# Documents saved in separate folders.
